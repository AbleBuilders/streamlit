# %% [markdown]
# # Import Libraries

# %%
# %matplotlib inline

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Download Data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

plt.figure(figsize = (10, 10))

for i in range(0,16):
    plt.subplot(4,4,i+1)
    plt.imshow(x_train[i], cmap = "binary")
    plt.xlabel(str(y_train[i]))
    plt.xticks([])
    plt.yticks([])

plt.show()

# %%
x_train = np.reshape(x_train,(60000, 28*28))
x_test = np.reshape(x_test, (10000, 28*28))
x_train = x_train/255
x_test= x_test/255

model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation = "sigmoid", input_shape=(784,)),
    tf.keras.layers.Dense(32, activation = "sigmoid"),
    tf.keras.layers.Dense(10, activation = "softmax")
])

model.compile(loss = "sparse_categorical_crossentropy",
             metrics = ["accuracy"],
             optimizer = "adam"
             )

model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs= 100,
         batch_size=1024)
# Out:
# Epoch 1/100
# 59/59 [==============================] - 1s 10ms/step - loss: 2.1682 - accuracy: 0.3544 - val_loss: 1.9413 - val_accuracy: 0.5548
# Epoch 2/100
# 59/59 [==============================] - 0s 8ms/step - loss: 1.7259 - accuracy: 0.6107 - val_loss: 1.4935 - val_accuracy: 0.6795
# Epoch 3/100
# 59/59 [==============================] - 0s 8ms/step - loss: 1.3253 - accuracy: 0.7268 - val_loss: 1.1490 - val_accuracy: 0.7806
# Epoch 4/100
# 59/59 [==============================] - 0s 8ms/step - loss: 1.0334 - accuracy: 0.8042 - val_loss: 0.9057 - val_accuracy: 0.8351
# Epoch 5/100
# 59/59 [==============================] - 0s 8ms/step - loss: 0.8255 - accuracy: 0.8458 - val_loss: 0.7316 - val_accuracy: 0.8668
# Epoch 6/100
# 59/59 [==============================] - 0s 8ms/step - loss: 0.6754 - accuracy: 0.8705 - val_loss: 0.6054 - val_accuracy: 0.8843
# Epoch 7/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.5669 - accuracy: 0.8855 - val_loss: 0.5147 - val_accuracy: 0.8938
# Epoch 8/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.4882 - accuracy: 0.8957 - val_loss: 0.4495 - val_accuracy: 0.9024
# Epoch 9/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.4307 - accuracy: 0.9034 - val_loss: 0.4018 - val_accuracy: 0.9098
# Epoch 10/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.3881 - accuracy: 0.9090 - val_loss: 0.3659 - val_accuracy: 0.9138
# Epoch 11/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.3552 - accuracy: 0.9147 - val_loss: 0.3387 - val_accuracy: 0.9157
# Epoch 12/100
# 59/59 [==============================] - 1s 10ms/step - loss: 0.3295 - accuracy: 0.9188 - val_loss: 0.3173 - val_accuracy: 0.9201
# Epoch 13/100
# 59/59 [==============================] - 1s 11ms/step - loss: 0.3082 - accuracy: 0.9224 - val_loss: 0.2990 - val_accuracy: 0.9234
# Epoch 14/100
# 59/59 [==============================] - 1s 11ms/step - loss: 0.2901 - accuracy: 0.9260 - val_loss: 0.2839 - val_accuracy: 0.9259
# Epoch 15/100
# 59/59 [==============================] - 1s 10ms/step - loss: 0.2746 - accuracy: 0.9296 - val_loss: 0.2707 - val_accuracy: 0.9287
# Epoch 16/100
# 59/59 [==============================] - 1s 14ms/step - loss: 0.2612 - accuracy: 0.9321 - val_loss: 0.2595 - val_accuracy: 0.9312
# Epoch 17/100
# 59/59 [==============================] - 1s 12ms/step - loss: 0.2490 - accuracy: 0.9355 - val_loss: 0.2490 - val_accuracy: 0.9337
# Epoch 18/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.2385 - accuracy: 0.9375 - val_loss: 0.2402 - val_accuracy: 0.9360
# Epoch 19/100
# 59/59 [==============================] - 1s 11ms/step - loss: 0.2291 - accuracy: 0.9400 - val_loss: 0.2333 - val_accuracy: 0.9367
# Epoch 20/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.2203 - accuracy: 0.9412 - val_loss: 0.2253 - val_accuracy: 0.9385
# Epoch 21/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.
100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0612 - accuracy: 0.9834 - val_loss: 0.1199 - val_accuracy: 0.9652
# Epoch 85/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0602 - accuracy: 0.9839 - val_loss: 0.1189 - val_accuracy: 0.9655
# Epoch 86/100
# 59/59 [==============================] - 1s 12ms/step - loss: 0.0590 - accuracy: 0.9840 - val_loss: 0.1193 - val_accuracy: 0.9652
# Epoch 87/100
# 59/59 [==============================] - 1s 12ms/step - loss: 0.0583 - accuracy: 0.9844 - val_loss: 0.1193 - val_accuracy: 0.9661
# Epoch 88/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0573 - accuracy: 0.9845 - val_loss: 0.1194 - val_accuracy: 0.9664
# Epoch 89/100
# 59/59 [==============================] - 1s 10ms/step - loss: 0.0566 - accuracy: 0.9848 - val_loss: 0.1187 - val_accuracy: 0.9654
# Epoch 90/100
# 59/59 [==============================] - 1s 10ms/step - loss: 0.0555 - accuracy: 0.9852 - val_loss: 0.1198 - val_accuracy: 0.9651
# Epoch 91/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0547 - accuracy: 0.9855 - val_loss: 0.1193 - val_accuracy: 0.9652
# Epoch 92/100
# 59/59 [==============================] - 1s 10ms/step - loss: 0.0540 - accuracy: 0.9858 - val_loss: 0.1196 - val_accuracy: 0.9657
# Epoch 93/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0533 - accuracy: 0.9858 - val_loss: 0.1197 - val_accuracy: 0.9660
# Epoch 94/100
# 59/59 [==============================] - 1s 10ms/step - loss: 0.0524 - accuracy: 0.9862 - val_loss: 0.1210 - val_accuracy: 0.9647
# Epoch 95/100
# 59/59 [==============================] - 1s 11ms/step - loss: 0.0517 - accuracy: 0.9862 - val_loss: 0.1198 - val_accuracy: 0.9656
# Epoch 96/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0510 - accuracy: 0.9862 - val_loss: 0.1197 - val_accuracy: 0.9660
# Epoch 97/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0500 - accuracy: 0.9870 - val_loss: 0.1209 - val_accuracy: 0.9656
# Epoch 98/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0493 - accuracy: 0.9873 - val_loss: 0.1207 - val_accuracy: 0.9653
# Epoch 99/100
# 59/59 [==============================] - 1s 9ms/step - loss: 0.0485 - accuracy: 0.9874 - val_loss: 0.1207 - val_accuracy: 0.9655
# Epoch 100/100
# 59/59 [==============================] - 1s 10ms/step - loss: 0.0479 - accuracy: 0.9875 - val_loss: 0.1204 - val_accuracy: 0.9655

# %%
model.save("model.h5")

# %% [markdown]
# # ML Server

# %%
# %%writefile ml_server.py

import json
import random
import tensorflow as tf
import numpy as np
from flask import Flask, request

app = Flask(__name__)

(_,_), (x_test, _) = tf.keras.datasets.mnist.load_data()
x_test= x_test/255

model = tf.keras.models.load_model("model.h5")
feature_model = tf.keras.models.Model(
    model.inputs,
    [layer.output for layer in model.layers]
)

def get_prediction():
    index = np.random.choice(x_test.shape[0])
    image = x_test[index, :, :]
    image_arr = np.reshape(image, (1, 784))
    return feature_model.predict(image_arr), image


@app.route("/", methods = ["GET", "POST"])
def index():
    if request.method == "POST":
        preds, image = get_prediction()
        final_pred = [p.tolist() for p in preds]
        return json.dumps({
            "prediction" : final_pred,
            "image" : image.tolist()
        })
    return "something."

if __name__ == "__main__":
    app.run()
# Out:
# Overwriting ml_server.py

# %% [markdown]
# # Streamlit Web App

# %%
# %%writefile app.py

import json
import requests
import matplotlib.pyplot as plt
import numpy as np
import streamlit as st

URI = "http://127.0.0.1/5000"

st.title("Neural Network Web App")
st.sidebar.markdown("## Input Images")

if st.button("Get some predictions"):
    response = requests.post(URI, data = {})
    reponse = json.loads(response.text)
    preds = response.get("prediction")
    image = response.get("image")
    image = np.reshape(image, (28, 28))
    
    st.image(image, width = 150)
# Out:
# Overwriting app.py
